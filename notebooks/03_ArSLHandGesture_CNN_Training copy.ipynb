# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import os
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.metrics import confusion_matrix, classification_report

# %%
# ======================
# CONFIG
# ======================
IMG = 128
BATCH = 32
EPOCHS = 60

BASE = os.getcwd()
DATA = os.path.join(BASE, "../data", "processed")
RAW = os.path.join(BASE, "../data", "structured")

# %%
# ======================
# DATA GENERATORS
# ======================
def preprocess(img):
    return img / 255.0

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True
)

# %%
val_gen = ImageDataGenerator(
    preprocessing_function=preprocess
)

# %%
train = train_gen.flow_from_directory(
    os.path.join(DATA, "train"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical"
)
# Out:
# Found 4651 images belonging to 28 classes.

# %%
valid = val_gen.flow_from_directory(
    os.path.join(DATA, "valid"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical",
    shuffle = False
)
# Out:
# Found 870 images belonging to 28 classes.

# %%
model = models.Sequential([
    layers.Conv2D(32, 3, padding="same", activation="relu", input_shape=(IMG, IMG, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(256, 3, padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),

    layers.Dense(256, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(train.num_classes, activation="softmax")
])
# Out:
# c:\Users\20100\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 28)             │         7,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 463,324 (1.77 MB)
#  Trainable params: 462,364 (1.76 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
callbacks = [
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=4,
        verbose=1
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    )
]

# %%
history = model.fit(
    train,
    validation_data=valid,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# c:\Users\20100\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 97s 647ms/step - accuracy: 0.0497 - loss: 3.4274 - val_accuracy: 0.0391 - val_loss: 3.7928 - learning_rate: 0.0010
# Epoch 2/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - accuracy: 0.0851 - loss: 3.2373 - val_accuracy: 0.0471 - val_loss: 3.8254 - learning_rate: 0.0010
# Epoch 3/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 329ms/step - accuracy: 0.0965 - loss: 3.1102 - val_accuracy: 0.0494 - val_loss: 3.7488 - learning_rate: 0.0010
# Epoch 4/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 329ms/step - accuracy: 0.1243 - loss: 3.0199 - val_accuracy: 0.0506 - val_loss: 3.7624 - learning_rate: 0.0010
# Epoch 5/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 51s 346ms/step - accuracy: 0.1696 - loss: 2.8638 - val_accuracy: 0.0908 - val_loss: 3.1815 - learning_rate: 0.0010
# Epoch 6/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 51s 350ms/step - accuracy: 0.2274 - loss: 2.7012 - val_accuracy: 0.1103 - val_loss: 3.4719 - learning_rate: 0.0010
# Epoch 7/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 51s 347ms/step - accuracy: 0.2907 - loss: 2.5073 - val_accuracy: 0.1253 - val_loss: 3.5959 - learning_rate: 0.0010
# Epoch 8/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 325ms/step - accuracy: 0.3601 - loss: 2.2832 - val_accuracy: 0.2920 - val_loss: 2.4194 - learning_rate: 0.0010
# Epoch 9/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 323ms/step - accuracy: 0.4187 - loss: 2.1155 - val_accuracy: 0.2057 - val_loss: 2.9085 - learning_rate: 0.0010
# Epoch 10/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 322ms/step - accuracy: 0.4652 - loss: 2.0172 - val_accuracy: 0.4379 - val_loss: 2.1946 - learning_rate: 0.0010
# Epoch 11/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 327ms/step - accuracy: 0.5257 - loss: 1.8707 - val_accuracy: 0.2172 - val_loss: 2.7811 - learning_rate: 0.0010
# Epoch 12/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 323ms/step - accuracy: 0.5971 - loss: 1.7303 - val_accuracy: 0.5632 - val_loss: 1.7997 - learning_rate: 0.0010
# Epoch 13/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 326ms/step - accuracy: 0.6484 - loss: 1.6107 - val_accuracy: 0.4678 - val_loss: 2.0356 - learning_rate: 0.0010
# Epoch 14/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 321ms/step - accuracy: 0.6829 - loss: 1.5083 - val_accuracy: 0.4920 - val_loss: 2.0088 - learning_rate: 0.0010
# Epoch 15/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 324ms/step - accuracy: 0.7381 - loss: 1.4400 - val_accuracy: 0.6759 - val_loss: 1.5167 - learning_rate: 0.0010
# Epoch 16/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 321ms/step - accuracy: 0.7489 - loss: 1.3816 - val_accuracy: 0.5874 - val_loss: 1.6969 - learning_rate: 0.0010
# Epoch 17/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 323ms/step - accuracy: 0.8064 - loss: 1.2880 - val_accuracy: 0.5563 - val_loss: 1.8773 - learning_rate: 0.0010
# Epoch 18/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 320ms/step - accuracy: 0.8300 - loss: 1.2274 - val_accuracy: 0.7241 - val_loss: 1.4430 - learning_rate: 0.0010
# Epoch 19/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 324ms/step - accuracy: 0.8426 - loss: 1.1774 - val_accuracy: 0.7828 - val_loss: 1.3130 - learning_rate: 0.0010
# Epoch 20/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 325ms/step - accuracy: 0.8703 - loss: 1.1394 - val_accuracy: 0.8138 - val_loss: 1.2434 - learning_rate: 0.0010
# Epoch 21/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - accuracy: 0.8630 - loss: 1.1366 - val_accuracy: 0.7839 - val_loss: 1.3159 - learning_rate: 0.0010
# Epoch 22/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 319ms/step - accuracy: 0.8837 - loss: 1.0886 - val_accuracy: 0.8057 - val_loss: 1.2330 - learning_rate: 0.0010
# Epoch 23/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 321ms/step - accuracy: 0.9056 - loss: 1.0529 - val_accuracy: 0.7609 - val_loss: 1.3503 - learning_rate: 0.0010
# Epoch 24/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 328ms/step - accuracy: 0.9013 - loss: 1.0389 - val_accuracy: 0.8092 - val_loss: 1.2676 - learning_rate: 0.0010
# Epoch 25/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 324ms/step - accuracy: 0.9194 - loss: 1.0096 - val_accuracy: 0.6230 - val_loss: 1.7151 - learning_rate: 0.0010
# Epoch 26/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 318ms/step - accuracy: 0.9276 - loss: 0.9925 - val_accuracy: 0.8839 - val_loss: 1.0531 - learning_rate: 0.0010
# Epoch 27/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 312ms/step - accuracy: 0.9226 - loss: 0.9782 - val_accuracy: 0.8138 - val_loss: 1.2338 - learning_rate: 0.0010
# Epoch 28/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 45s 309ms/step - accuracy: 0.9406 - loss: 0.9547 - val_accuracy: 0.8471 - val_loss: 1.1238 - learning_rate: 0.0010
# Epoch 29/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 45s 309ms/step - accuracy: 0.9408 - loss: 0.9432 - val_accuracy: 0.8690 - val_loss: 1.0573 - learning_rate: 0.0010
# Epoch 30/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 314ms/step - accuracy: 0.9482 - loss: 0.9314 - val_accuracy: 0.8862 - val_loss: 1.0401 - learning_rate: 0.0010
# Epoch 31/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 321ms/step - accuracy: 0.9409 - loss: 0.9481 - val_accuracy: 0.8678 - val_loss: 1.0930 - learning_rate: 0.0010
# Epoch 32/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - accuracy: 0.9491 - loss: 0.9309 - val_accuracy: 0.8379 - val_loss: 1.1665 - learning_rate: 0.0010
# Epoch 33/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 317ms/step - accuracy: 0.9565 - loss: 0.9040 - val_accuracy: 0.8333 - val_loss: 1.1575 - learning_rate: 0.0010
# Epoch 34/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9566 - loss: 0.9060
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 327ms/step - accuracy: 0.9565 - loss: 0.9060 - val_accuracy: 0.7023 - val_loss: 1.5174 - learning_rate: 0.0010
# Epoch 35/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - accuracy: 0.9643 - loss: 0.8785 - val_accuracy: 0.9241 - val_loss: 0.9482 - learning_rate: 3.0000e-04
# Epoch 36/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 50s 339ms/step - accuracy: 0.9799 - loss: 0.8410 - val_accuracy: 0.9333 - val_loss: 0.9343 - learning_rate: 3.0000e-04
# Epoch 37/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 327ms/step - accuracy: 0.9773 - loss: 0.8386 - val_accuracy: 0.9241 - val_loss: 0.9535 - learning_rate: 3.0000e-04
# Epoch 38/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 50s 341ms/step - accuracy: 0.9816 - loss: 0.8338 - val_accuracy: 0.9011 - val_loss: 1.0305 - learning_rate: 3.0000e-04
# Epoch 39/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 330ms/step - accuracy: 0.9802 - loss: 0.8296 - val_accuracy: 0.9402 - val_loss: 0.9109 - learning_rate: 3.0000e-04
# Epoch 40/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 50s 339ms/step - accuracy: 0.9834 - loss: 0.8235 - val_accuracy: 0.9195 - val_loss: 0.9610 - learning_rate: 3.0000e-04
# Epoch 41/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 52s 356ms/step - accuracy: 0.9846 - loss: 0.8205 - val_accuracy: 0.9069 - val_loss: 0.9734 - learning_rate: 3.0000e-04
# Epoch 42/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 45s 307ms/step - accuracy: 0.9844 - loss: 0.8254 - val_accuracy: 0.9437 - val_loss: 0.9060 - learning_rate: 3.0000e-04
# Epoch 43/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 45s 310ms/step - accuracy: 0.9872 - loss: 0.8216 - val_accuracy: 0.9310 - val_loss: 0.9174 - learning_rate: 3.0000e-04
# Epoch 44/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 49s 334ms/step - accuracy: 0.9885 - loss: 0.8148 - val_accuracy: 0.9057 - val_loss: 1.0126 - learning_rate: 3.0000e-04
# Epoch 45/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 321ms/step - accuracy: 0.9831 - loss: 0.8220 - val_accuracy: 0.9184 - val_loss: 0.9861 - learning_rate: 3.0000e-04
# Epoch 46/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9860 - loss: 0.8147
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 326ms/step - accuracy: 0.9860 - loss: 0.8147 - val_accuracy: 0.9103 - val_loss: 1.0062 - learning_rate: 3.0000e-04
# Epoch 47/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 327ms/step - accuracy: 0.9857 - loss: 0.8024 - val_accuracy: 0.9379 - val_loss: 0.9146 - learning_rate: 9.0000e-05
# Epoch 48/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 49s 335ms/step - accuracy: 0.9865 - loss: 0.8034 - val_accuracy: 0.9379 - val_loss: 0.9096 - learning_rate: 9.0000e-05
# Epoch 49/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 48s 331ms/step - accuracy: 0.9885 - loss: 0.8037 - val_accuracy: 0.9322 - val_loss: 0.9373 - learning_rate: 9.0000e-05
# Epoch 50/60
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9906 - loss: 0.8004
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 47s 322ms/step - accuracy: 0.9906 - loss: 0.8004 - val_accuracy: 0.9391 - val_loss: 0.9125 - learning_rate: 9.0000e-05

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history):
    plt.figure(figsize=(14,5))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

plot_learning_curves(history)

# %%
test_gen = ImageDataGenerator(preprocessing_function=preprocess)

test = test_gen.flow_from_directory(
    os.path.join(RAW, "test_structured"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical",
)

model.evaluate(test)
# Out:
# Found 290 images belonging to 28 classes.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9109 - loss: 1.0053
# [1.0242984294891357, 0.9034482836723328]

# %%
MODELS_PATH = os.path.join(BASE, "../models", "ArSL_Model_v2_NoCrop.keras")
model.save(MODELS_PATH)

# %%
train_no_shuffle = train_gen.flow_from_directory(
    os.path.join(DATA, "train"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical",
    shuffle=False
)

train_preds = model.predict(train_no_shuffle)
y_trained_pred = np.argmax(train_preds, axis=1)
y_trained_true = train_no_shuffle.classes
# Out:
# Found 4651 images belonging to 28 classes.
# c:\Users\20100\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step

# %%
class_names = list(train_no_shuffle.class_indices.keys())

cm = confusion_matrix(y_trained_true, y_trained_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification Report
report = classification_report(y_trained_true, y_trained_pred, target_names=class_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ALIF       0.99      1.00      1.00       155
#          AYN       1.00      1.00      1.00       163
#          BAA       1.00      1.00      1.00       155
#          DAD       1.00      1.00      1.00       190
#         DELL       1.00      1.00      1.00       161
#         DHAA       1.00      0.99      1.00       164
#        DHELL       1.00      1.00      1.00       168
#          FAA       1.00      0.99      1.00       164
#        GHAYN       1.00      1.00      1.00       165
#           HA       1.00      1.00      1.00       163
#          HAA       0.98      1.00      0.99       160
#         JEEM       1.00      0.98      0.99       160
#         KAAF       0.99      1.00      1.00       168
#         KHAA       1.00      1.00      1.00       160
#         LAAM       0.99      0.99      0.99       163
#         MEEM       1.00      0.99      0.99       163
#         NOON       0.99      1.00      1.00       163
#         QAAF       0.99      1.00      0.99       164
#          RAA       1.00      1.00      1.00       172
#          SAD       1.00      0.99      1.00       188
#         SEEN       1.00      1.00      1.00       174
#        SHEEN       1.00      1.00      1.00       181
#           TA       1.00      1.00      1.00       159
#          TAA       1.00      1.00      1.00       173
#          THA       1.00      0.99      1.00       161
#          WAW       0.99      1.00      1.00       165
#           YA       0.99      0.99      0.99       163
#          ZAY       1.00      1.00      1.00       166
#
#     accuracy                           1.00      4651
#    macro avg       1.00      1.00      1.00      4651
# weighted avg       1.00      1.00      1.00      4651

# %%
valid_no_Shuffle = val_gen.flow_from_directory(
    os.path.join(DATA, "valid"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 870 images belonging to 28 classes.

# %%
vaild_preds = model.predict(valid_no_Shuffle)
y_valid_pred = np.argmax(vaild_preds, axis=1)
y_valid_true = valid_no_Shuffle.classes
class_names = list(valid_no_Shuffle.class_indices.keys())

cm = confusion_matrix(y_valid_true, y_valid_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# c:\Users\20100\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step

# %%
# Classification Report
report = classification_report(y_valid_true, y_valid_pred, target_names=class_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ALIF       0.90      0.97      0.93        29
#          AYN       1.00      1.00      1.00        30
#          BAA       0.96      0.93      0.95        28
#          DAD       0.95      1.00      0.97        35
#         DELL       0.94      1.00      0.97        30
#         DHAA       1.00      1.00      1.00        31
#        DHELL       0.97      0.97      0.97        32
#          FAA       0.97      0.90      0.93        31
#        GHAYN       1.00      0.97      0.98        31
#           HA       1.00      1.00      1.00        30
#          HAA       0.90      0.90      0.90        30
#         JEEM       0.97      0.93      0.95        30
#         KAAF       0.97      0.94      0.95        31
#         KHAA       0.88      1.00      0.94        30
#         LAAM       0.97      0.94      0.95        31
#         MEEM       0.97      0.94      0.95        31
#         NOON       1.00      0.97      0.98        30
#         QAAF       0.91      0.94      0.92        31
#          RAA       1.00      0.97      0.98        32
#          SAD       0.95      1.00      0.97        35
#         SEEN       1.00      1.00      1.00        33
#        SHEEN       1.00      1.00      1.00        34
#           TA       1.00      1.00      1.00        30
#          TAA       1.00      0.97      0.98        33
#          THA       0.93      0.90      0.92        30
#          WAW       1.00      1.00      1.00        31
#           YA       0.97      0.93      0.95        30
#          ZAY       1.00      1.00      1.00        31
#
#     accuracy                           0.97       870
#    macro avg       0.97      0.97      0.97       870
# weighted avg       0.97      0.97      0.97       870

# %%
test_no_shuffle = test_gen.flow_from_directory(
    os.path.join(DATA, "test"),
    target_size=(IMG, IMG),
    batch_size=BATCH,
    class_mode="categorical",
    shuffle = False
)
# Out:
# Found 290 images belonging to 28 classes.

# %%
preds = model.predict(test_no_shuffle)
y_pred = np.argmax(preds, axis=1)
y_true = test_no_shuffle.classes
class_names = list(test_no_shuffle.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# c:\Users\20100\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
# Classification Report
report = classification_report(y_true, y_pred, target_names=class_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ALIF       0.91      1.00      0.95        10
#          AYN       0.91      1.00      0.95        10
#          BAA       1.00      1.00      1.00        10
#          DAD       1.00      1.00      1.00        12
#         DELL       1.00      0.90      0.95        10
#         DHAA       1.00      0.90      0.95        10
#        DHELL       1.00      0.82      0.90        11
#          FAA       0.90      0.90      0.90        10
#        GHAYN       1.00      1.00      1.00        10
#           HA       0.91      1.00      0.95        10
#          HAA       0.90      0.90      0.90        10
#         JEEM       1.00      1.00      1.00        10
#         KAAF       1.00      1.00      1.00        11
#         KHAA       0.82      0.90      0.86        10
#         LAAM       0.91      1.00      0.95        10
#         MEEM       1.00      0.90      0.95        10
#         NOON       1.00      1.00      1.00        10
#         QAAF       0.90      0.90      0.90        10
#          RAA       1.00      1.00      1.00        11
#          SAD       0.92      1.00      0.96        12
#         SEEN       1.00      1.00      1.00        11
#        SHEEN       1.00      0.91      0.95        11
#           TA       0.91      1.00      0.95        10
#          TAA       1.00      0.91      0.95        11
#          THA       1.00      0.90      0.95        10
#          WAW       1.00      0.90      0.95        10
#           YA       0.91      1.00      0.95        10
#          ZAY       0.91      1.00      0.95        10
#
#     accuracy                           0.96       290
#    macro avg       0.96      0.95      0.95       290
# weighted avg       0.96      0.96      0.96       290
